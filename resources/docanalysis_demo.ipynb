# %% [markdown]
# ## All imports

# %%
# !pip install docanalysis
# !docanalysis --help
# Out:
# Requirement already satisfied: docanalysis in c:\users\shweata\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: tkinterweb==3.10.7 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (3.10.7)
# Requirement already satisfied: setuptools==60.3.1 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (60.3.1)
# Requirement already satisfied: yake==0.4.8 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (0.4.8)
# Requirement already satisfied: coloredlogs==15.0.1 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (15.0.1)
# Requirement already satisfied: nltk==3.6.7 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (3.6.7)
# Requirement already satisfied: tqdm==4.62.3 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (4.62.3)
# Requirement already satisfied: spacy==3.0.7 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (3.0.7)
# Requirement already satisfied: ConfigArgParse==1.5.3 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (1.5.3)
# Requirement already satisfied: pytest==6.2.5 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (6.2.5)
# Requirement already satisfied: py4ami==0.0.16 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (0.0.16)
# Requirement already satisfied: scispacy in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (0.4.0)
# Requirement already satisfied: pandas==1.3.4 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (1.3.4)
# Requirement already satisfied: braceexpand==0.1.7 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (0.1.7)
# Requirement already satisfied: beautifulsoup4==4.10.0 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (4.10.0)
# Requirement already satisfied: pygetpapers==1.1.2 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (1.1.2)
# Requirement already satisfied: lxml==4.7.1 in c:\users\shweata\anaconda3\lib\site-packages (from docanalysis) (4.7.1)
# Requirement already satisfied: pillow in c:\users\shweata\anaconda3\lib\site-packages (from tkinterweb==3.10.7->docanalysis) (7.2.0)
# Requirement already satisfied: segtok in c:\users\shweata\anaconda3\lib\site-packages (from yake==0.4.8->docanalysis) (1.5.10)
# Requirement already satisfied: numpy in c:\users\shweata\anaconda3\lib\site-packages (from yake==0.4.8->docanalysis) (1.18.5)
# Requirement already satisfied: click>=6.0 in c:\users\shweata\anaconda3\lib\site-packages (from yake==0.4.8->docanalysis) (7.1.2)
# Requirement already satisfied: tabulate in c:\users\shweata\anaconda3\lib\site-packages (from yake==0.4.8->docanalysis) (0.8.9)
# Requirement already satisfied: jellyfish in c:\users\shweata\anaconda3\lib\site-packages (from yake==0.4.8->docanalysis) (0.8.8)
# Requirement already satisfied: networkx in c:\users\shweata\anaconda3\lib\site-packages (from yake==0.4.8->docanalysis) (2.4)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\shweata\anaconda3\lib\site-packages (from coloredlogs==15.0.1->docanalysis) (10.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\shweata\anaconda3\lib\site-packages (from nltk==3.6.7->docanalysis) (2022.1.18)
# Requirement already satisfied: joblib in c:\users\shweata\anaconda3\lib\site-packages (from nltk==3.6.7->docanalysis) (0.16.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\shweata\anaconda3\lib\site-packages (from tqdm==4.62.3->docanalysis) (0.4.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (3.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (2.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (1.7.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (8.0.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (2.0.4)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (0.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (2.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (0.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (20.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (2.24.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (0.7.4)
# Requirement already satisfied: jinja2 in c:\users\shweata\anaconda3\lib\site-packages (from spacy==3.0.7->docanalysis) (2.11.2)
# Requirement already satisfied: atomicwrites>=1.0; sys_platform == "win32" in c:\users\shweata\anaconda3\lib\site-packages (from pytest==6.2.5->docanalysis) (1.4.0)
# Requirement already satisfied: toml in c:\users\shweata\anaconda3\lib\site-packages (from pytest==6.2.5->docanalysis) (0.10.1)
# Requirement already satisfied: py>=1.8.2 in c:\users\shweata\anaconda3\lib\site-packages (from pytest==6.2.5->docanalysis) (1.9.0)
# Requirement already satisfied: iniconfig in c:\users\shweata\anaconda3\lib\site-packages (from pytest==6.2.5->docanalysis) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\shweata\anaconda3\lib\site-packages (from pytest==6.2.5->docanalysis) (19.3.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\shweata\anaconda3\lib\site-packages (from pytest==6.2.5->docanalysis) (0.13.1)
# Requirement already satisfied: python-rake in c:\users\shweata\anaconda3\lib\site-packages (from py4ami==0.0.16->docanalysis) (1.5.0)
# Requirement already satisfied: tkinterhtml in c:\users\shweata\anaconda3\lib\site-packages (from py4ami==0.0.16->docanalysis) (0.7)
# Requirement already satisfied: pdfminer3 in c:\users\shweata\anaconda3\lib\site-packages (from py4ami==0.0.16->docanalysis) (2018.12.3.0)
# Requirement already satisfied: SPARQLWrapper in c:\users\shweata\anaconda3\lib\site-packages (from py4ami==0.0.16->docanalysis) (1.8.5)
# Requirement already satisfied: matplotlib in c:\users\shweata\anaconda3\lib\site-packages (from py4ami==0.0.16->docanalysis) (3.2.2)
# Requirement already satisfied: PyPDF2 in c:\users\shweata\anaconda3\lib\site-packages (from py4ami==0.0.16->docanalysis) (1.26.0)
# Requirement already satisfied: psutil in c:\users\shweata\anaconda3\lib\site-packages (from py4ami==0.0.16->docanalysis) (5.7.0)
# Requirement already satisfied: pysbd in c:\users\shweata\anaconda3\lib\site-packages (from scispacy->docanalysis) (0.3.4)
# Requirement already satisfied: conllu in c:\users\shweata\anaconda3\lib\site-packages (from scispacy->docanalysis) (4.4.1)
# Requirement already satisfied: nmslib>=1.7.3.6 in c:\users\shweata\anaconda3\lib\site-packages (from scispacy->docanalysis) (2.1.1)
# Requirement already satisfied: scikit-learn>=0.20.3 in c:\users\shweata\anaconda3\lib\site-packages (from scispacy->docanalysis) (0.23.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\shweata\anaconda3\lib\site-packages (from pandas==1.3.4->docanalysis) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\shweata\anaconda3\lib\site-packages (from pandas==1.3.4->docanalysis) (2.8.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shweata\anaconda3\lib\site-packages (from beautifulsoup4==4.10.0->docanalysis) (2.0.1)
# Requirement already satisfied: habanero in c:\users\shweata\anaconda3\lib\site-packages (from pygetpapers==1.1.2->docanalysis) (1.0.0)
# Requirement already satisfied: arxiv in c:\users\shweata\anaconda3\lib\site-packages (from pygetpapers==1.1.2->docanalysis) (1.4.2)
# Requirement already satisfied: xmltodict in c:\users\shweata\anaconda3\lib\site-packages (from pygetpapers==1.1.2->docanalysis) (0.12.0)
# Requirement already satisfied: dict2xml in c:\users\shweata\anaconda3\lib\site-packages (from pygetpapers==1.1.2->docanalysis) (1.7.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\shweata\anaconda3\lib\site-packages (from networkx->yake==0.4.8->docanalysis) (4.4.2)
# Requirement already satisfied: pyreadline3; sys_platform == "win32" and python_version >= "3.8" in c:\users\shweata\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs==15.0.1->docanalysis) (3.4.1)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\shweata\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy==3.0.7->docanalysis) (3.0.0)
# Requirement already satisfied: six in c:\users\shweata\anaconda3\lib\site-packages (from packaging>=20.0->spacy==3.0.7->docanalysis) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\shweata\anaconda3\lib\site-packages (from packaging>=20.0->spacy==3.0.7->docanalysis) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shweata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\shweata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\shweata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\shweata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\shweata\anaconda3\lib\site-packages (from jinja2->spacy==3.0.7->docanalysis) (1.1.1)
# Requirement already satisfied: sortedcontainers in c:\users\shweata\anaconda3\lib\site-packages (from pdfminer3->py4ami==0.0.16->docanalysis) (2.2.2)
# Requirement already satisfied: pycryptodome in c:\users\shweata\anaconda3\lib\site-packages (from pdfminer3->py4ami==0.0.16->docanalysis) (3.14.1)
# Requirement already satisfied: rdflib>=4.0 in c:\users\shweata\anaconda3\lib\site-packages (from SPARQLWrapper->py4ami==0.0.16->docanalysis) (5.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shweata\anaconda3\lib\site-packages (from matplotlib->py4ami==0.0.16->docanalysis) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shweata\anaconda3\lib\site-packages (from matplotlib->py4ami==0.0.16->docanalysis) (0.10.0)
# Requirement already satisfied: pybind11<2.6.2 in c:\users\shweata\anaconda3\lib\site-packages (from nmslib>=1.7.3.6->scispacy->docanalysis) (2.6.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shweata\anaconda3\lib\site-packages (from scikit-learn>=0.20.3->scispacy->docanalysis) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\shweata\anaconda3\lib\site-packages (from scikit-learn>=0.20.3->scispacy->docanalysis) (1.5.0)
# Requirement already satisfied: feedparser in c:\users\shweata\anaconda3\lib\site-packages (from arxiv->pygetpapers==1.1.2->docanalysis) (6.0.8)
# Requirement already satisfied: isodate in c:\users\shweata\anaconda3\lib\site-packages (from rdflib>=4.0->SPARQLWrapper->py4ami==0.0.16->docanalysis) (0.6.0)
# Requirement already satisfied: sgmllib3k in c:\users\shweata\anaconda3\lib\site-packages (from feedparser->arxiv->pygetpapers==1.1.2->docanalysis) (1.0.0)
#
#
# Failed to import tensorflow. Please note that tensorflow is not installed by default when you install tensorflow_hub. This is so that users can decide which tensorflow package to use. To use tensorflow_hub, please install a current version of tensorflow by following the instructions at https://tensorflow.org/install and https://tensorflow.org/hub/installation.
# c:\users\shweata\anaconda3\lib\site-packages\_distutils_hack\__init__.py:36: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Traceback (most recent call last):
#   File "c:\users\shweata\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\shweata\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\shweata\anaconda3\Scripts\docanalysis.exe\__main__.py", line 4, in <module>
#   File "c:\users\shweata\anaconda3\lib\site-packages\docanalysis\docanalysis.py", line 9, in <module>
#     from docanalysis.entity_extraction import EntityExtraction
#   File "c:\users\shweata\anaconda3\lib\site-packages\docanalysis\entity_extraction.py", line 24, in <module>
#     nlp = spacy.load('en_core_sci_sm')
#   File "c:\users\shweata\anaconda3\lib\site-packages\spacy\__init__.py", line 50, in load
#     return util.load_model(
#   File "c:\users\shweata\anaconda3\lib\site-packages\spacy\util.py", line 324, in load_model
#     return load_model_from_package(name, **kwargs)
#   File "c:\users\shweata\anaconda3\lib\site-packages\spacy\util.py", line 357, in load_model_from_package
#     return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)
#   File "c:\users\shweata\anaconda3\lib\site-packages\en_core_sci_sm\__init__.py", line 10, in load
#     return load_model_from_init_py(__file__, **overrides)
#   File "c:\users\shweata\anaconda3\lib\site-packages\spacy\util.py", line 517, in load_model_from_init_py
#     return load_model_from_path(
#   File "c:\users\shweata\anaconda3\lib\site-packages\spacy\util.py", line 392, in load_model_from_path
#     nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
#   File "c:\users\shweata\anaconda3\lib\site-packages\spacy\util.py", line 429, in load_model_from_config
#     nlp = lang_cls.from_config(
#   File "c:\users\shweata\anaconda3\lib\site-packages\spacy\language.py", line 1644, in from_config
#     nlp = lang_cls(vocab=vocab, create_tokenizer=create_tokenizer, meta=meta)
#   File "c:\users\shweata\anaconda3\lib\site-packages\spacy\language.py", line 151, in __init__
#     util.registry._entry_point_factories.get_all()
#   File "c:\users\shweata\anaconda3\lib\site-packages\catalogue\__init__.py", line 108, in get_all
#     result.update(self.get_entry_points())
#   File "c:\users\shweata\anaconda3\lib\site-packages\catalogue\__init__.py", line 123, in get_entry_points
#     result[entry_point.name] = entry_point.load()
#   File "c:\users\shweata\anaconda3\lib\importlib\metadata.py", line 77, in load
#     module = import_module(match.group('module'))
#   File "c:\users\shweata\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\shweata\AppData\Roaming\Python\Python38\site-packages\spacy_universal_sentence_encoder\__init__.py", line 13, in <module>
#     from . import language
#   File "C:\Users\shweata\AppData\Roaming\Python\Python38\site-packages\spacy_universal_sentence_encoder\language.py", line 7, in <module>
#     import tensorflow_hub as hub
#   File "C:\Users\shweata\AppData\Roaming\Python\Python38\site-packages\tensorflow_hub\__init__.py", line 85, in <module>
#     _ensure_tf_install()
#   File "C:\Users\shweata\AppData\Roaming\Python\Python38\site-packages\tensorflow_hub\__init__.py", line 49, in _ensure_tf_install
#     import tensorflow as tf
#   File "C:\Users\shweata\AppData\Roaming\Python\Python38\site-packages\tensorflow\__init__.py", line 41, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "C:\Users\shweata\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\__init__.py", line 40, in <module>
#     from tensorflow.python.eager import context
#   File "C:\Users\shweata\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\context.py", line 32, in <module>
#     from tensorflow.core.framework import function_pb2
#   File "C:\Users\shweata\AppData\Roaming\Python\Python38\site-packages\tensorflow\core\framework\function_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/70576776/153189376-98ed4cd6-7861-4d85-b537-d71ef38e5c31.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/70576776/153190644-e1fdb7ce-15f0-47e5-9f25-183170363174.png)

# %%
# !docanalysis --run_pygetpapers "XANES AND EXAFS AND XRD" -k 10 --project_name xanes_madices --run_sectioning

# %% [markdown]
# ## 1. Query [`pygetpapers`](https://pypi.org/project/pygetpapers/)
# `pygetpapers` is a command-line tool which downloads open scientific papers from repositories like EPMC, biorxiv, arxiv, and so on.
# ![image](https://user-images.githubusercontent.com/70576776/130623817-73596788-a3b1-4a35-9332-1d0cf375a7d7.png)
#
#
# `pygetpapers` gives us:
# ![image](https://user-images.githubusercontent.com/70576776/130625542-192e3133-91d7-4b6d-815f-9cc3db924a4f.png)

# %% [markdown]
# ## 2. Section papers using [`ami-section`](https://github.com/petermr/ami3)
# We use `ami`'s sectioning functionality to create smaller sections (like Introduction, Method, Results, Figures, and so on) for each paper.
# ![image](https://user-images.githubusercontent.com/70576776/130624722-aecb3ff3-c26c-490a-92c5-30bb98b25318.png)
#
# After ami-section:
# ![image](https://user-images.githubusercontent.com/70576776/130625282-407b6f91-7ed6-4735-90e7-6334bd798f97.png)

# %% [markdown]
# ## Step 3 and 4: Extract Entities and Make dictionary

# %%
# !docanalysis --project_name xanes_madices --output entities_20220209 --make_ami_dict entities_20220209

# %% [markdown]
# ### Useful terms extracted:
# ```
# 'surface', 30,
#  'redox', 25,
# 'NIB', 18,
# 'sXAS', 16,
# 'mRIXS', 15
# 'Fe', 13,
# 'TM', 13,
# 'DNN', 12,
# 'MSE', 11,
# 'capacity', 11,
# 'surfaces', 10,
# 'Mn', 9,
# 'spectra', 7,
# 'Ti', 7,
# 'N', 7,
# 'Al', 7,
# 'XANES spectra', 6…
# ![image.png](attachment:image.png)
# ```
